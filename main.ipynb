# %%
# !pip install pygame
import pygame
from checkers.constants import *
from checkers.board import Board
from checkers.game import Game

# dummy video driver in case of executing on deepnote
# import os
# os.environ["SDL_VIDEODRIVER"] = "dummy"

win = pygame.display.set_mode((Width,Height))
pygame.display.set_caption('Checkers')
FPS = 60
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting pygame
#   Downloading pygame-2.0.1-cp37-cp37m-manylinux1_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 13.3 MB/s
# Installing collected packages: pygame
# Successfully installed pygame-2.0.1
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-7ec0b611115f> in <module>
#       9 # os.environ["SDL_VIDEODRIVER"] = "dummy"
#      10
# ---> 11 win = pygame.display.set_mode((Width,Height))
#      12 pygame.display.set_caption('Checkers')
#      13 FPS = 60
#
# error: No available video device
